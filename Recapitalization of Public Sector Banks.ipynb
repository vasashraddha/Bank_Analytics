# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
  
# %matplotlib inline

# %%
df=pd.read_csv('bank-full.csv',delimiter =",")
df.head()
# Out:
#    age           job  marital  education default  balance housing loan  \
# 0   58    management  married   tertiary      no     2143     yes   no
# 1   44    technician   single  secondary      no       29     yes   no
# 2   33  entrepreneur  married  secondary      no        2     yes  yes
# 3   47   blue-collar  married    unknown      no     1506     yes   no
# 4   33       unknown   single    unknown      no        1      no   no
#
#    contact  day month  duration  campaign  pdays  previous poutcome deposit
# 0  unknown    5   may       261         1     -1         0  unknown      no
# 1  unknown    5   may       151         1     -1         0  unknown      no
# 2  unknown    5   may        76         1     -1         0  unknown      no
# 3  unknown    5   may        92         1     -1         0  unknown      no
# 4  unknown    5   may       198         1     -1         0  unknown      no

# %%
df.shape
# Out:
# (45211, 17)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45211 entries, 0 to 45210
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        45211 non-null  int64
#  1   job        45211 non-null  object
#  2   marital    45211 non-null  object
#  3   education  45211 non-null  object
#  4   default    45211 non-null  object
#  5   balance    45211 non-null  int64
#  6   housing    45211 non-null  object
#  7   loan       45211 non-null  object
#  8   contact    45211 non-null  object
#  9   day        45211 non-null  int64
#  10  month      45211 non-null  object
#  11  duration   45211 non-null  int64
#  12  campaign   45211 non-null  int64
#  13  pdays      45211 non-null  int64
#  14  previous   45211 non-null  int64
#  15  poutcome   45211 non-null  object
#  16  deposit    45211 non-null  object
# dtypes: int64(7), object(10)
# memory usage: 5.9+ MB

# %%
df.isnull().values.any()
# Out:
# False

# %%
df.describe().T.head()
# Out:
#             count         mean          std     min    25%    50%     75%  \
# age       45211.0    40.936210    10.618762    18.0   33.0   39.0    48.0
# balance   45211.0  1362.272058  3044.765829 -8019.0   72.0  448.0  1428.0
# day       45211.0    15.806419     8.322476     1.0    8.0   16.0    21.0
# duration  45211.0   258.163080   257.527812     0.0  103.0  180.0   319.0
# campaign  45211.0     2.763841     3.098021     1.0    1.0    2.0     3.0
#
#                max
# age           95.0
# balance   102127.0
# day           31.0
# duration    4918.0
# campaign      63.0

# %%
df[df['education'] == 'secondary'].head(10)
# Out:
#     age           job   marital  education default  balance housing loan  \
# 1    44    technician    single  secondary      no       29     yes   no
# 2    33  entrepreneur   married  secondary      no        2     yes  yes
# 9    43    technician    single  secondary      no      593     yes   no
# 10   41        admin.  divorced  secondary      no      270     yes   no
# 11   29        admin.    single  secondary      no      390     yes   no
# 12   53    technician   married  secondary      no        6     yes   no
# 14   57      services   married  secondary      no      162     yes   no
# 19   33      services   married  secondary      no        0     yes   no
# 20   28   blue-collar   married  secondary      no      723     yes  yes
# 23   25      services   married  secondary      no       50     yes   no
#
#     contact  day month  duration  campaign  pdays  previous poutcome deposit
# 1   unknown    5   may       151         1     -1         0  unknown      no
# ...

# %%
df
# Out:
#        age           job   marital  education default  balance housing loan  \
# 0       58    management   married   tertiary      no     2143     yes   no
# 1       44    technician    single  secondary      no       29     yes   no
# 2       33  entrepreneur   married  secondary      no        2     yes  yes
# 3       47   blue-collar   married    unknown      no     1506     yes   no
# 4       33       unknown    single    unknown      no        1      no   no
# ...    ...           ...       ...        ...     ...      ...     ...  ...
# 45206   51    technician   married   tertiary      no      825      no   no
# 45207   71       retired  divorced    primary      no     1729      no   no
# 45208   72       retired   married  secondary      no     5715      no   no
# 45209   57   blue-collar   married  secondary      no      668      no   no
# 45210   37  entrepreneur   married  secondary      no     2971      no   no
#
# ...

# %%
df.dtypes.tail()
# Out:
# campaign     int64
# pdays        int64
# previous     int64
# poutcome    object
# deposit     object
# dtype: object

# %%
df.columns.values
# Out:
# array(['age', 'job', 'marital', 'education', 'default', 'balance',
#        'housing', 'loan', 'contact', 'day', 'month', 'duration',
#        'campaign', 'pdays', 'previous', 'poutcome', 'deposit'],
#       dtype=object)

# %%
df.groupby('deposit').mean()
# Out:
#                age      balance        day    duration  campaign      pdays  \
# deposit
# no       40.838986  1303.714969  15.892290  221.182806  2.846350  36.421372
# yes      41.670070  1804.267915  15.158253  537.294574  2.141047  68.702968
#
#          previous
# deposit
# no       0.502154
# yes      1.170354

# %% [markdown]
# <b>Note below how Dataset is unbalanced</b>

# %%
df['deposit'].value_counts()
# Out:
# no     39922
# yes     5289
# Name: deposit, dtype: int64

# %%
countNo = len(df[df.deposit == 'no'])
countYes = len(df[df.deposit == 'yes'])
print('Percentage of "No": {:.3f}%'. format((countNo/(len(df.deposit))*100)))
print('Percentage of "Yes": {:.3f}%'. format((countYes/(len(df.deposit))*100)))
# Out:
# Percentage of "No": 88.302%
# Percentage of "Yes": 11.698%

# %%
for col_name in df.columns:
    if df[col_name].dtypes == 'int64':
        unique_cat = len(df[col_name].unique())
        print("Feature '{col_name}' has {unique_cat} unique categories".format(col_name=col_name, unique_cat=unique_cat))
# Out:
# Feature 'age' has 77 unique categories
# Feature 'balance' has 7168 unique categories
# Feature 'day' has 31 unique categories
# Feature 'duration' has 1573 unique categories
# Feature 'campaign' has 48 unique categories
# Feature 'pdays' has 559 unique categories
# Feature 'previous' has 41 unique categories

# %%
df['balance'].value_counts().sort_values(ascending=False).head()
# Out:
# 0    3514
# 1     195
# 2     156
# 4     139
# 3     134
# Name: balance, dtype: int64

# %%
pd.crosstab(df.age, df.housing, margins = True).style.background_gradient(cmap='OrRd')
# Out:
# <style  type="text/css" >
#     #T_78b5e5e2_e66e_11eb_a8f4_84a93eb1c5darow0_col0 {
#             background-color:  #fff7ec;
#             color:  #000000;
#         }    #T_78b5e5e2_e66e_11eb_a8f4_84a93eb1c5darow0_col1 {
#             background-color:  #fff7ec;
#             color:  #000000;
#         }    #T_78b5e5e2_e66e_11eb_a8f4_84a93eb1c5darow0_col2 {
#             background-color:  #fff7ec;
#             color:  #000000;
#         }    #T_78b5e5e2_e66e_11eb_a8f4_84a93eb1c5darow1_col0 {
#             background-color:  #fff7ec;
#             color:  #000000;
#         }    #T_78b5e5e2_e66e_11eb_a8f4_84a93eb1c5darow1_col1 {
#             background-color:  #fff7ec;
#             color:  #000000;
#         }    #T_78b5e5e2_e66e_11eb_a8f4_84a93eb1c5darow1_col2 {
#             background-color:  #fff7ec;
#             color:  #000000;
#         }    #T_78b5e5e2_e66e_11eb_a8f4_84a93eb1c5darow2_col0 {
#             background-color:  #fff7ec;
#             color:  #000000;
# ...

# %%
import seaborn as sns
from matplotlib import gridspec
import matplotlib.cm as cm

# %%
with sns.axes_style('whitegrid'):
    label_freq = df['housing'].value_counts() / len(df)
    print(label_freq)
# Out:
# yes    0.555838
# no     0.444162
# Name: housing, dtype: float64

# %%
with sns.axes_style('whitegrid'):
    fig = label_freq.sort_values(ascending=False).plot.bar(figsize=(10,5),
                                                           align='center',
                                                           color='indianred')
    fig.axhline(y=0.10, color='red')
    fig.set_ylabel('percentage of Housing within each category')
    fig.set_xlabel('Variable: Housing')
    fig.set_title('Identifying Categories')
    plt.xticks(rotation=45)
    plt.show()

# %%
with sns.axes_style('whitegrid'):
    df.groupby(['day']).day.count().plot(kind='barh',
                                      title='Plotting records by day type', 
                                      figsize=(15,10),color='salmon',
                                      align='center')

# %%
sns.countplot(x=df['deposit'],palette='viridis')

# %%
sns.countplot(x=df['job'],palette='Blues')
plt.xticks(rotation=90)
plt.show()

# %%
sns.countplot(x=df['month'],palette='Purples')

# %%
fig = plt.figure(figsize = (10,7))
sns.clustermap(df.corr(),cmap="GnBu")

# %%
# Constructing a correlation matrix.
corr_mat = df.corr()
plt.figure(figsize = (15,15))
sns.heatmap(data = corr_mat, cmap = 'Set2', annot = True, linewidths=1.5)
plt.show()

# %%
print(df['housing'].value_counts())
# Out:
# yes    25130
# no     20081
# Name: housing, dtype: int64

# %%
with sns.axes_style('whitegrid'):
    plt.figure(figsize=(10,10))
    sns.boxplot(x='job',
            y='age',
            data=df,
            palette="Set3")
    plt.axhline(y=-0.5, xmin=0.3, xmax=1,dashes=(5,5), c='g')
    plt.axhline(y=0.3, xmin=0.3, dashes=(5,5), c='m')
    plt.ylabel('Angle between X-axis and Gravity_mean')
    plt.xticks(rotation=90)
    plt.show()

# %%
sns.FacetGrid(df,hue="job",size=5, palette="Set1").map(plt.scatter,"age","marital").add_legend();
plt.show()

# %%
sns.FacetGrid(df,hue="job",size=5, 
              palette="Set1").map(plt.scatter,
                                  "age","contact").add_legend();
plt.show()

# %%
sns.pairplot(df,hue="job",size=3,
             palette="husl")

# %%
with sns.axes_style('whitegrid'):
    plt.figure(figsize=(7,7))
    sns.barplot(x='job', y='campaign',data=df,
            palette="Pastel2",
            linewidth=3)
    plt.xticks(rotation=90)
    plt.show()

# %%
sns.catplot(x="job", 
            y="campaign",
            data=df, 
            kind="violin",
            height=10,
             palette="RdPu",
            aspect=3,
            hue_order= "Activity")
plt.show()

# %%
with sns.axes_style('darkgrid'):
    plt.figure(figsize=(14,10))
    plt.title('loan as per the day')
    g = sns.countplot(x='day',hue='loan', 
                      data=df, palette = 'Spectral')

# %%
#Verifying null values
sns.heatmap(df.isnull(), yticklabels=False, cbar=False, cmap='viridis')

# %%
df.isna().any()
# Out:
# age          False
# job          False
# marital      False
# education    False
# default      False
# balance      False
# housing      False
# loan         False
# contact      False
# day          False
# month        False
# duration     False
# campaign     False
# pdays        False
# previous     False
# poutcome     False
# deposit      False
# dtype: bool

# %%
eduRatio = pd.DataFrame({'Job' : []})
for i in df["job"].unique():
    eduRatio = eduRatio.append(df[(df["job"] == i)]["education"].value_counts().to_frame().iloc[0] * 100 / df[(df["job"] == i)]["education"].value_counts().sum())
eduRatio["Job"] = df["job"].unique()
eduRatio
# Out:
#                      Job  education
# tertiary      management  82.480440
# secondary     technician  68.829801
# tertiary    entrepreneur  46.133154
# secondary    blue-collar  55.189067
# unknown          unknown  44.097222
# secondary        retired  43.462898
# secondary         admin.  81.589635
# secondary       services  83.220992
# tertiary   self-employed  52.754908
# secondary     unemployed  55.871067
# primary        housemaid  50.564516
# secondary        student  54.157783

# %%
#Define X and y
X = df.drop(['deposit','job','marital', 'education', 'contact', 
             'housing', 'loan', 'day', 'month', 'poutcome' ], axis=1)
Y = df['deposit']

# %%
X = pd.get_dummies(X)
Y = pd.get_dummies(Y)

# %%
X.columns
X = X.drop(['default_no'], axis= 1)
X = X.rename(columns = {'default_yes': 'default'})
Y.columns
Y = Y.drop(['yes'], axis=1)
Y = Y.rename(columns= {'no': 'deposit'})

# %%
#Age group
bins = range(0, 100, 10)
ax = sns.distplot(df.age[df.deposit=='yes'],
              color='red', kde=False, bins=bins, label='Have Subscribed')
sns.distplot(df.age[df.deposit=='no'],
         ax=ax,  # Overplots on first plot
         color='green', kde=False, bins=bins, label="Haven't Subscribed")
plt.legend()
plt.show()

# %%
# Distribution of default feature
sns.countplot(df.default)
plt.xticks(rotation=0)
plt.show()

# %%
pd.crosstab(df.age,df.deposit).plot(kind="bar",figsize=(20,6))
plt.title('Client Subscribed Frequency for Ages')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %%
pd.crosstab(df.marital,df.deposit).plot(kind="bar",figsize=(15,6),color=['navy','blue' ])
plt.title('Client Subscribed Frequency for Maritial')
plt.xlabel('marital')
plt.xticks(rotation=0)
plt.legend(["Haven't Subscribed", "Have Subscribed"])
plt.ylabel('Frequency')
plt.show()

# %%
plt.scatter(x=df.age[df.deposit=='yes'], y=df.duration[(df.deposit=='yes')], c="pink")
plt.scatter(x=df.age[df.deposit=='no'], y=df.duration[(df.deposit=='no')], c="purple")
plt.legend(["Have Subscribed", "Haven't Subscribed"])
plt.xlabel("Age")
plt.ylabel("Duration")
plt.show()

# %%
sns.scatterplot(x='age', y='balance',hue='deposit', data=df)

# %%
sns.distplot(df.age, bins = 20)

# %%
sns.distplot(df.balance, bins = 20)

# %%
## Correlation with independent Variable 
df.corrwith(Y.deposit).plot.barh(
        figsize = (10, 10), title = "Correlation with Y", fontsize = 15,
        rot = 45, grid = True)

# %%
## Correlation Matrix
sns.set(style="white")

# Compute the correlation matrix
corr = df.corr()

# Generate a mask for the upper triangle
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(10, 10))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %%
sns.pairplot(data=df, hue='deposit', 
             vars= ['age', 'balance', 'duration'],
            palette='pink')

# %%
sns.countplot(x='education', data=df, label='Count',palette='magma')

# %%
corr = df.corr()
corr.style.background_gradient(cmap='PuBu')
# Out:
# <style  type="text/css" >
#     #T_b678da26_e66e_11eb_b414_84a93eb1c5darow0_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_b678da26_e66e_11eb_b414_84a93eb1c5darow0_col1 {
#             background-color:  #eee9f3;
#             color:  #000000;
#         }    #T_b678da26_e66e_11eb_b414_84a93eb1c5darow0_col2 {
#             background-color:  #f4edf6;
#             color:  #000000;
#         }    #T_b678da26_e66e_11eb_b414_84a93eb1c5darow0_col3 {
#             background-color:  #f4eef6;
#             color:  #000000;
#         }    #T_b678da26_e66e_11eb_b414_84a93eb1c5darow0_col4 {
#             background-color:  #f2ecf5;
#             color:  #000000;
#         }    #T_b678da26_e66e_11eb_b414_84a93eb1c5darow0_col5 {
#             background-color:  #f5eff6;
#             color:  #000000;
#         }    #T_b678da26_e66e_11eb_b414_84a93eb1c5darow0_col6 {
#             background-color:  #f8f1f8;
#             color:  #000000;
# ...

# %%
 #month
pd.crosstab(df.month,df.deposit).plot(kind="bar",figsize=(20,6))
plt.title('Client Subscribed Frequency for Month')
plt.xlabel('Month')
plt.ylabel('Frequency')
plt.show()

# %%
for column in df.columns:
    print(column,df[column].nunique())
# Out:
# age 77
# job 12
# marital 3
# education 4
# default 2
# balance 7168
# housing 2
# loan 2
# contact 3
# day 31
# month 12
# duration 1573
# campaign 48
# pdays 559
# previous 41
# poutcome 4
# deposit 2

# %%
categorical_features=[feature for feature in df.columns if ((df[feature].dtypes=='O') & (feature not in ['deposit']))]
categorical_features
# Out:
# ['job',
#  'marital',
#  'education',
#  'default',
#  'housing',
#  'loan',
#  'contact',
#  'month',
#  'poutcome']

# %%
plt.figure(figsize=(15,50), facecolor='white')
plotnumber =1
for categorical_feature in categorical_features:
    ax = plt.subplot(12,3,plotnumber)
    sns.countplot(y=categorical_feature,data=df)
    plt.xlabel(categorical_feature)
    plt.title(categorical_feature)
    plotnumber+=1
plt.show()

# %% [markdown]
# <b>Take-away:</b>
# * client with job type as management records are high in given dataset and housemaid are significantly less
# * client who married is high in records in a given dataset and divorced are less
# * client whose education background is secondary are in high numbers in a given dataset
# * default feature seems to do not play an essential role as it has the value of no at a high ratio to value yes, which can drop data in the month of may is high and less in dec

# %%
# numerical features
numerical_features = [cols for cols in df.columns if df[cols].dtype != 'O']
numerical_features = df[numerical_features]
numerical_features.head()
# Out:
#    age  balance  day  duration  campaign  pdays  previous
# 0   58     2143    5       261         1     -1         0
# 1   44       29    5       151         1     -1         0
# 2   33        2    5        76         1     -1         0
# 3   47     1506    5        92         1     -1         0
# 4   33        1    5       198         1     -1         0

# %%
numerical_features.describe()
# Out:
#                 age        balance           day      duration      campaign  \
# count  45211.000000   45211.000000  45211.000000  45211.000000  45211.000000
# mean      40.936210    1362.272058     15.806419    258.163080      2.763841
# std       10.618762    3044.765829      8.322476    257.527812      3.098021
# min       18.000000   -8019.000000      1.000000      0.000000      1.000000
# 25%       33.000000      72.000000      8.000000    103.000000      1.000000
# 50%       39.000000     448.000000     16.000000    180.000000      2.000000
# 75%       48.000000    1428.000000     21.000000    319.000000      3.000000
# max       95.000000  102127.000000     31.000000   4918.000000     63.000000
#
#               pdays      previous
# count  45211.000000  45211.000000
# mean      40.197828      0.580323
# std      100.128746      2.303441
# min       -1.000000      0.000000
# 25%       -1.000000      0.000000
# 50%       -1.000000      0.000000
# ...

# %%
numerical_features.hist(figsize = (15,15), color="tan")
plt.show()

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.25, stratify=Y, random_state=10)

# %%
print('Training data size : ', X_train.shape)
print('Test data size : ', X_test.shape)
# Out:
# Training data size :  (33908, 7)
# Test data size :  (11303, 7)

# %%
print('Training model with {} dimensions.'.format(X_train.shape[1]))
print('\nTesting model with {} dimensions.'.format(X_test.shape[1]))
# Out:
# Training model with 7 dimensions.
#
# Testing model with 7 dimensions.

# %%
Training_to_original_ratio = round(X_train.shape[0]/(df.shape[0]), 2) * 100

Testing_to_original_ratio = round(X_test.shape[0]/(df.shape[0]), 2) * 100

print ('As shown below {}% of the data is for training and the rest {}% is for testing.'.format(Training_to_original_ratio, 
                                                                                               Testing_to_original_ratio))
list(zip(["Training set", "Testing set"],
   [Training_to_original_ratio, Testing_to_original_ratio]))
# Out:
# As shown below 75.0% of the data is for training and the rest 25.0% is for testing.
# [('Training set', 75.0), ('Testing set', 25.0)]

# %%
Y_train['deposit'].value_counts()
# Out:
# 1    29941
# 0     3967
# Name: deposit, dtype: int64

# %%
from sklearn.model_selection import cross_val_score, StratifiedKFold, RandomizedSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression, SGDClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from xgboost import XGBClassifier
from sklearn.metrics import make_scorer, accuracy_score
import time
from sklearn.cluster import KMeans

# %%
# Standardize the data
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
X_scaled = pd.DataFrame(X_scaled, columns=X.columns)

# %%
skf = StratifiedKFold(n_splits=5, random_state=None)

# %%
# Baseline models
baseline_model_dict = {}

# %%
# K Nearest Neighbors (KNN)
knn = KNeighborsClassifier()
knn_results = cross_val_score(knn, X_scaled, Y, cv=skf)
print("KNN Accuracy: %.2f%%" % (knn_results.mean() * 100.0))
baseline_model_dict['KNN'] = knn_results.mean() * 100.0
# Out:
# KNN Accuracy: 86.42%

# %%
# Logistic Regression
lr = LogisticRegression()
lr_results = cross_val_score(lr, X_scaled, Y, cv=skf)
print("LogReg Accuracy: %.2f%%" % (lr_results.mean() * 100.0))
baseline_model_dict['LogReg'] = lr_results.mean() * 100.0
# Out:
# LogReg Accuracy: 88.45%

# %%
# Support Vector Classifier
svc = SVC()
svc_results = cross_val_score(svc, X_scaled, Y, cv=skf)
print("SVC Accuracy: %.2f%%" % (svc_results.mean() * 100.0))
baseline_model_dict['SVC'] = svc_results.mean() * 100.0
# Out:
# SVC Accuracy: 87.31%

# %%
# Naive Bayes
nb = GaussianNB()
nb_results = cross_val_score(nb, X_scaled, Y, cv=skf)
print("NB Accuracy: %.2f%%" % (nb_results.mean() * 100.0))
baseline_model_dict['NB'] = nb_results.mean() * 100.0
# Out:
# NB Accuracy: 82.74%

# %%
# Random Forest
rf = RandomForestClassifier()
rf_results = cross_val_score(rf, X_scaled, Y, cv=skf)
print("Random Forest Accuracy: %.2f%%" % (rf_results.mean() * 100.0))
baseline_model_dict['Random Forest'] = rf_results.mean() * 100.0
# Out:
# Random Forest Accuracy: 84.82%

# %%
# Gradient Boosting Classifier
gbc = GradientBoostingClassifier()
gbc_results = cross_val_score(gbc, X_scaled, Y, cv=skf)
print("GBC Accuracy: %.2f%%" % (gbc_results.mean() * 100.0))
baseline_model_dict['GBC'] = gbc_results.mean() * 100.0
# Out:
# GBC Accuracy: 85.43%

# %%
# XGBoost Classifier
xgb = XGBClassifier()
xgb_results = cross_val_score(xgb, X_scaled, Y, cv=skf)
print("XGB Accuracy: %.2f%%" % (xgb_results.mean() * 100.0))
baseline_model_dict['XGB'] = xgb_results.mean() * 100.0
# Out:
# [01:22:08] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [01:22:11] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [01:22:13] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# ...

# %%
# Plot Baseline Model Accuracies
keys = baseline_model_dict.keys()
values = baseline_model_dict.values()

fig1, ax1 = plt.subplots()
ax1.bar(keys, values)
ax1.set_xlabel('Baseline Models')
ax1.set_ylabel('Accuracy(%)')
ax1.set_xticklabels(keys, rotation=70)
plt.show()
